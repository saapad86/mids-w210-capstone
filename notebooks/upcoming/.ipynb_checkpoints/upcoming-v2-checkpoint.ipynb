# %%
import os
import sys
paths = {
    'helpers': '/home/spadela/mids-w210-capstone'
}
for k,v in paths.items():
    sys.path.insert(0, v)
    
import requests
import pandas as pd
import numpy as np
import datetime
from copy import deepcopy

from bs4 import BeautifulSoup

### Set Up Mongo Connection
from db import dbToolsMongo
db = dbToolsMongo()

import time
import urllib.parse

pd.set_option('display.max_columns', 500)

# %reload_ext autoreload
# %autoreload 2

# %%
filters = {
    'ico_dates': {'$ne': None}
}
df1 = db.toDF('icotracker_ico',filters)
df1.head()
# Out:
#   ICO_JOIN_KEY                       _id      base  \
# 0       patron  5b1c8cf448d6215496c4d2c0  Ethereum
# 1    cryptonvc  5b1c8cf448d6215496c4d2c1  Ethereum
# 2         sosr  5b1c8cf548d6215496c4d2c2  Ethereum
# 3      dynatiq  5b1c8ef048d6215496c4d2c4  Ethereum
# 4       3ccoin  5b1c8ef048d6215496c4d2c5     Waves
#
#                   bonus_details  cluster_pca  \
# 0  Start Bonus: 35% - Raised: 0          NaN
# 1  Start Bonus: 30% - Raised: 0          NaN
# 2  Start Bonus: 25% - Raised: 0          NaN
# 3  Start Bonus: 50% - Raised: 0          NaN
# 4  Start Bonus: 50% - Raised: 0          NaN
#
#                              company_url  \
# 0                 https://patron-ico.io/
# 1                     http://crypton.vc/
# 2  https://www.sosrcoin.io/en/index.html
# 3                   https://dynatiq.com/
# 4                  https://3ccoin.io/en/
#
#                                          description    escrow_class  \
# 0  A decentralized platform which shares economie...  [fa, fa-close]
# 1  A Blockchain-based cryptocurrency venture capi...  [fa, fa-close]
# 2  A cryptocurrency focusing on solving waste pro...  [fa, fa-close]
# 3  A Blockchain-based marketplace for domains and...  [fa, fa-close]
# 4  A Blockchain-based option to invest in the pro...  [fa, fa-close]
#
#   escrow_href                             ico_dates  \
# 0         NaN  09/05/2018 00:00:00 UTC - 09/06/2018
# 1         NaN  29/03/2018 00:00:00 UTC - 09/06/2018
# 2         NaN  10/04/2018 00:00:00 UTC - 09/06/2018
# 3         NaN  25/04/2018 00:00:00 UTC - 09/06/2018
# 4         NaN  10/05/2018 00:00:00 UTC - 10/06/2018
#
#                        ico_sold_status        name  \
# 0  ICO: 240,000,000 PAT of 400,000,000      PATRON
# 1    ICO: 50,400,000 CRN of 72,000,000  Crypton VC
# 2   ICO: 45,000,000 SOSR of 50,000,000        SOSR
# 3    ICO: 10,000,000 DTQ of 11,000,000     Dynatiq
# 4                      ICO: ~ 3cCoin ~      3cCoin
#
#                               owner_linkedin_profile         owner_name  \
# 0     https://www.linkedin.com/in/atsushi-hisatsumi/  Atsushi Hisatsumi
# 1           https://www.linkedin.com/in/jaceknowak2/        Jacek Nowak
# 2  https://icotracker.net/www.linkedin.com/in/cha...           Zhen Lin
# 3             https://www.linkedin.com/in/abdaluzza/        Abd al Uzza
# 4               https://www.facebook.com/asb-service     Alexey Butorin
#
#                                               social     status  \
# 0  {'Telegram': 'https://t.me/patronicoen', 'Face...  no_reddit
# 1  {'Github': 'https://github.com/CryptonVC', 'Te...  no_reddit
# 2              {'Telegram': 'https://t.me/sosrcoin'}  no_reddit
# 3  {'Blog': 'https://medium.com/@dynatiq', 'Teleg...  no_reddit
# 4  {'Youtube': 'https://www.youtube.com/channel/U...  no_reddit
#
#                                  tracker_url  \
# 0      https://icotracker.net/project/patron
# 1  https://icotracker.net/project/crypton_vc
# 2        https://icotracker.net/project/sosr
# 3     https://icotracker.net/project/dynatiq
# 4      https://icotracker.net/project/3ccoin
#
#                                           whitepaper
# 0  https://patron-ico.io/doc/patron-wp-en-01-2018...
# 1     http://crypton.vc/assets/files/white-paper.pdf
# 2  https://drive.google.com/file/d/1jHYIt6TZm3ZTB...
# 3                 https://dynatiq.com/whitepaper.pdf
# 4  https://3ccoin.io/download/en/3cCoin_crowdsale...

# %%
df2 = db.toDF('sp_hype_score')
len(df2)

# %%
df2.head()

# %%
compare = pd.merge(df1,df2,on='ICO_JOIN_KEY',how='outer',indicator=True)
compare.head()

# %%
compare.groupby(['_merge']).agg('count')

# %% [markdown]
# ### Current & Upcoming ICOs
#
# Build a dataset of current or upcoming ICOs (starting in next 30 days).

# %%
import datetime

def parse_iso_dates(dates_text,returnType='datetime'):
    dates = []
    for txt in dates_text.split(' '):
        try:
            valid_date = datetime.datetime.strptime(txt.strip(),'%d/%m/%Y')
            if returnType == 'string':
                dates.append(datetime.datetime.strftime(valid_date,'%d/%m/%Y'))
            else:
                dates.append(valid_date)
        except ValueError as e:
            # Not a date, fail silently...
            pass
    if len(dates) == 1:
        dates = dates*2
    return dates

df1['ico_start_datetime'] = df1.apply(lambda x: parse_iso_dates(x['ico_dates'])[0],axis=1)
df1['ico_end_datetime'] = df1.apply(lambda x: parse_iso_dates(x['ico_dates'])[1],axis=1)
df1['ico_start_date'] = df1.apply(lambda x: parse_iso_dates(x['ico_dates'],'string')[0],axis=1)
df1['ico_end_date'] = df1.apply(lambda x: parse_iso_dates(x['ico_dates'],'string')[1],axis=1)

start_date = datetime.datetime(2018,8,1,0,0)
end_date = start_date + datetime.timedelta(days=90)

# %%
df1[df1['ICO_JOIN_KEY'] == 'starta']
# Out:
#      ICO_JOIN_KEY                       _id   base  \
# 2539       starta  5b1c955d48d6215496c4dcb5  Waves
#
#                         bonus_details  cluster_pca  \
# 2539  Start Bonus: 0% - Raised: 1,828          NaN
#
#                         company_url           description    escrow_class  \
# 2539  http://startaaccelerator.com/  Business Accelerator  [fa, fa-close]
#
#      escrow_href                             ico_dates  ico_sold_status  \
# 2539         NaN  04/07/2017 00:00:00 UTC - 03/08/2017  ICO: ~ Starta ~
#
#         name owner_linkedin_profile    owner_name  \
# 2539  Starta                    NaN  Alexey Girin
#
#                                                  social     status  \
# 2539  {'Twitter': 'https://twitter.com/startaico', '...  no_reddit
#
#                                 tracker_url  \
# 2539  https://icotracker.net/project/starta
#
#                                          whitepaper   ico_start_datetime  \
# 2539  https://startaico.com/Starta-Whitepaper-1.pdf  2017-07-04 00:00:00
#
#      ico_end_datetime ico_start_date ico_end_date
# 2539       2017-08-03     04/07/2017   03/08/2017

# %% [markdown]
# ### Append Reddit/Social/Ratings Data

# %%
df2 = df1[(df1['ico_end_datetime'] >= start_date - datetime.timedelta(days=365)) & (df1['ico_start_datetime'] <= end_date)]
reddit = db.toDF('reddit_summary')
df2 = pd.merge(df2,reddit[['ICO','Total_Score']],left_on='name',right_on='ICO',how='left')

social = db.toDF('ico_social_media_stats')
df2 = pd.merge(df2,social[['name','twitter_followers','facebook_followers']],left_on='name',right_on='name',how='left')

ratings = db.toDF('icorating_ratings').drop_duplicates(subset=['ICO_JOIN_KEY'])
ratings.columns = ['hype_score','ICO_JOIN_KEY','name','risk_score','startup_name','status','symbol','_id']
ratings = ratings[['ICO_JOIN_KEY','startup_name','status','symbol']]
df2 = pd.merge(df2,ratings[['ICO_JOIN_KEY','symbol']],left_on='ICO_JOIN_KEY',right_on='ICO_JOIN_KEY',how='inner')

hype_codes = db.toDF('sp_hype_score')
df2 = pd.merge(df2,hype_codes,left_on='ICO_JOIN_KEY',right_on='ICO_JOIN_KEY',how='left')
df2['risk_score'] = df2.apply(lambda x: 'LOW' if x['RISK_CODE'] > 1 else 'HIGH', axis=1)
df2['hype_score'] = df2.apply(lambda x: 'HIGH' if x['HYPE_CODE_BINARY'] == 1 else 'LOW', axis=1)

def recode_3pt(val,options=['HIGH','MEDIUM','LOW']):
    if pd.isna(val):
        return options[1]
    elif str(val) == '1.0':
        return options[0]
    elif str(val) == '0.0':
        return options[1]
    elif str(val) == '-1.0':
        return options[2]
    else:
        return options[1]
    
reddit_scores = db.toDF('Reddit_Data')
reddit_scores['ICO'] = reddit_scores['ICO'].apply(lambda x: x.lower())
df2 = pd.merge(df2,reddit_scores[['ICO','RISK_CODE_TERTIARY','HYPE_CODE_TERTIARY','Stanford_Sentiment_Score_Proc']],left_on='ICO_JOIN_KEY',right_on='ICO',how='left')
df2['risk_score'] = df2.apply(lambda x: recode_3pt(x['RISK_CODE_TERTIARY'],options=['HIGH','MED','LOW']),axis=1)
df2['hype_score'] = df2.apply(lambda x: recode_3pt(x['HYPE_CODE_TERTIARY'],options=['HIGH','MED','LOW']),axis=1)
df2['sentiment_score'] = df2.apply(lambda x: recode_3pt(x['Stanford_Sentiment_Score_Proc'],options=['POSITIVE','NEUTRAL','NEGATIVE']),axis=1)

price_features = db.toDF('sp_price_features')
df2 = pd.merge(df2,price_features[['ICO_JOIN_KEY','EXG_PRICE_RATING','pch7']],left_on='ICO_JOIN_KEY',right_on='ICO_JOIN_KEY',how='left')
df2['volatility_score'] = df2.apply(lambda x: recode_3pt(x['EXG_PRICE_RATING'],options=['LOW','MED','HIGH']),axis=1)

df2.head()
# Out:
#   ICO_JOIN_KEY                     _id_x      base  \
# 0    cryptonvc  5b1c8cf448d6215496c4d2c1  Ethereum
# 1         sosr  5b1c8cf548d6215496c4d2c2  Ethereum
# 2      dynatiq  5b1c8ef048d6215496c4d2c4  Ethereum
# 3   cellblocks  5b1c8f2148d6215496c4d2c8  Ethereum
# 4     cryptics  5b1c8f2148d6215496c4d2c9  Ethereum
#
#                   bonus_details  cluster_pca  \
# 0  Start Bonus: 30% - Raised: 0          NaN
# 1  Start Bonus: 25% - Raised: 0          NaN
# 2  Start Bonus: 50% - Raised: 0          NaN
# 3   Start Bonus: 0% - Raised: 0          NaN
# 4  Start Bonus: 72% - Raised: 0          NaN
#
#                              company_url  \
# 0                     http://crypton.vc/
# 1  https://www.sosrcoin.io/en/index.html
# 2                   https://dynatiq.com/
# 3                 https://cellblocks.io/
# 4                  http://cryptics.tech/
#
#                                          description    escrow_class  \
# 0  A Blockchain-based cryptocurrency venture capi...  [fa, fa-close]
# 1  A cryptocurrency focusing on solving waste pro...  [fa, fa-close]
# 2  A Blockchain-based marketplace for domains and...  [fa, fa-close]
# 3  A digital solution to an outdated and corrupt ...  [fa, fa-close]
# 4       An AI-based public crypto analytics platform  [fa, fa-close]
#
#   escrow_href                             ico_dates  \
# 0         NaN  29/03/2018 00:00:00 UTC - 09/06/2018
# 1         NaN  10/04/2018 00:00:00 UTC - 09/06/2018
# 2         NaN  25/04/2018 00:00:00 UTC - 09/06/2018
# 3         NaN  01/04/2018 10:00:00 UTC - 10/06/2018
# 4         NaN  10/05/2018 12:00:00 UTC - 10/06/2018
#
#                         ico_sold_status        name  \
# 0     ICO: 50,400,000 CRN of 72,000,000  Crypton VC
# 1    ICO: 45,000,000 SOSR of 50,000,000        SOSR
# 2     ICO: 10,000,000 DTQ of 11,000,000     Dynatiq
# 3  ICO: 187,500,000 CLBK of 250,000,000  CellBlocks
# 4    ICO: 66,000,000 QRP of 100,000,000    Cryptics
#
#                               owner_linkedin_profile      owner_name  \
# 0           https://www.linkedin.com/in/jaceknowak2/     Jacek Nowak
# 1  https://icotracker.net/www.linkedin.com/in/cha...        Zhen Lin
# 2             https://www.linkedin.com/in/abdaluzza/     Abd al Uzza
# 3           https://www.linkedin.com/in/jonascbrown/     Jonas Brown
# 4  https://www.linkedin.com/in/stanislav-maer-110...  Stanislav Maer
#
#                                               social     status  \
# 0  {'Github': 'https://github.com/CryptonVC', 'Te...  no_reddit
# 1              {'Telegram': 'https://t.me/sosrcoin'}  no_reddit
# 2  {'Blog': 'https://medium.com/@dynatiq', 'Teleg...  no_reddit
# 3  {'Reddit': 'https://www.reddit.com/user/cellbl...   not_a_sr
# 4  {'Github': 'https://github.com/CrypticsAI', 'T...  no_reddit
#
#                                  tracker_url  \
# 0  https://icotracker.net/project/crypton_vc
# 1        https://icotracker.net/project/sosr
# 2     https://icotracker.net/project/dynatiq
# 3  https://icotracker.net/project/cellblocks
# 4    https://icotracker.net/project/cryptics
#
#                                           whitepaper   ico_start_datetime  \
# 0     http://crypton.vc/assets/files/white-paper.pdf  2018-03-29 00:00:00
# 1  https://drive.google.com/file/d/1jHYIt6TZm3ZTB...  2018-04-10 00:00:00
# 2                 https://dynatiq.com/whitepaper.pdf  2018-04-25 00:00:00
# 3               https://cellblocks.io/whitepaper.pdf  2018-04-01 00:00:00
# 4   https://cryptics.tech/Whitepaper-Cryptics-EN.pdf  2018-05-10 00:00:00
#
#   ico_end_datetime ico_start_date ico_end_date ICO_x  Total_Score  \
# 0       2018-06-09     29/03/2018   09/06/2018   NaN          NaN
# 1       2018-06-09     10/04/2018   09/06/2018   NaN          NaN
# 2       2018-06-09     25/04/2018   09/06/2018   NaN          NaN
# 3       2018-06-10     01/04/2018   10/06/2018   NaN          NaN
# 4       2018-06-10     10/05/2018   10/06/2018   NaN          NaN
#
#   twitter_followers facebook_followers symbol HYPE SCORE  HYPE_CODE_BINARY  \
# 0               NaN                NaN    CRN        NaN               NaN
# 1               NaN                NaN   SOSR        NaN               NaN
# 2               NaN                NaN    DTQ       HIGH               1.0
# 3               NaN                NaN   CLBK       HIGH               1.0
# 4               NaN                NaN    QRP        NaN               NaN
#
#   RISK SCORE  RISK_CODE                     _id_y risk_score hype_score  \
# 0        NaN        NaN                       NaN        MED        MED
# 1        NaN        NaN                       NaN        MED        MED
# 2        LOW        4.0  5b4fde7857c4101afecebb4a       HIGH        MED
# 3        LOW        4.0  5b4fde7857c4101afeceba6f       HIGH        MED
# 4        NaN        NaN                       NaN        MED        MED
#
#         ICO_y  RISK_CODE_TERTIARY  HYPE_CODE_TERTIARY  \
# 0         NaN                 NaN                 NaN
# 1         NaN                 NaN                 NaN
# 2     dynatiq                 1.0                 0.0
# 3  cellblocks                 1.0                 0.0
# 4         NaN                 NaN                 NaN
#
#    Stanford_Sentiment_Score_Proc sentiment_score  EXG_PRICE_RATING  pch7  \
# 0                            NaN         NEUTRAL               NaN   NaN
# 1                            NaN         NEUTRAL               NaN   NaN
# 2                            0.0         NEUTRAL               NaN   NaN
# 3                            0.0         NEUTRAL               NaN   NaN
# 4                            NaN         NEUTRAL               NaN   NaN
#
#   volatility_score
# 0              MED
# 1              MED
# 2              MED
# 3              MED
# 4              MED

# %%
df2[df2['ICO_JOIN_KEY'] == 'starta']
# Out:
#     ICO_JOIN_KEY                     _id_x   base  \
# 731       starta  5b1c955d48d6215496c4dcb5  Waves
#
#                        bonus_details  cluster_pca  \
# 731  Start Bonus: 0% - Raised: 1,828          NaN
#
#                        company_url           description    escrow_class  \
# 731  http://startaaccelerator.com/  Business Accelerator  [fa, fa-close]
#
#     escrow_href                             ico_dates  ico_sold_status  \
# 731         NaN  04/07/2017 00:00:00 UTC - 03/08/2017  ICO: ~ Starta ~
#
#        name owner_linkedin_profile    owner_name  \
# 731  Starta                    NaN  Alexey Girin
#
#                                                 social     status  \
# 731  {'Twitter': 'https://twitter.com/startaico', '...  no_reddit
#
#                                tracker_url  \
# 731  https://icotracker.net/project/starta
#
#                                         whitepaper   ico_start_datetime  \
# 731  https://startaico.com/Starta-Whitepaper-1.pdf  2017-07-04 00:00:00
#
#     ico_end_datetime ico_start_date ico_end_date ICO_x  Total_Score  \
# 731       2017-08-03     04/07/2017   03/08/2017   NaN          NaN
#
#     twitter_followers facebook_followers symbol HYPE SCORE  HYPE_CODE_BINARY  \
# 731               NaN                NaN    CRS       HIGH               1.0
#
#     RISK SCORE  RISK_CODE                     _id_y risk_score hype_score  \
# 731        LOW        2.0  5b4fde7857c4101afeceb839        LOW       HIGH
#
#       ICO_y  RISK_CODE_TERTIARY  HYPE_CODE_TERTIARY  \
# 731  starta                -1.0                 1.0
#
#      Stanford_Sentiment_Score_Proc sentiment_score  EXG_PRICE_RATING  pch7  \
# 731                            1.0        POSITIVE               1.0 -0.38
#
#     volatility_score
# 731              LOW

# %%
df2.groupby(['volatility_score']).aggregate({'ICO_JOIN_KEY': 'count'})
# Out:
#                   ICO_JOIN_KEY
# volatility_score
# HIGH                         8
# MED                        180

# %% [markdown]
# ### Pre-Process Data for Display

# %%
def owner_url(row):
    if pd.notna(row['owner_linkedin_profile']):
        links = [{'label': str(row['owner_name']), 'url': str(row['owner_linkedin_profile'])}]
        owner_url = make_link(links)
    else:
        owner_url = str(row['owner_name'])
    return owner_url
        

def get_links(row):
    links = []
    if len(str(row['company_url'])) > 1:
        links.append({'label': 'URL', 'url': row['company_url']})
    if len(str(row['whitepaper'])) > 1:
        links.append({'label': 'Whitepaper', 'url': row['whitepaper']})
    # parse social dict
    for k,v in row['social'].items():
        links.append({'label': k, 'url': v})
    
    return links

def make_link(links):
    html = ''
    for l in links:
        html += "<a href='{url}'>{label}</url>".format(label=l['label'],url=l['url']) + '<br/>'
        
    return html

df2['name_url'] = df2.apply(lambda x: str(x['name']) + '|' + '/detail/' + x['name'],axis=1)
df2['owner_url'] = df2.apply(lambda x: owner_url(x),axis=1)
df2['links'] = df2.apply(lambda x: make_link(get_links(x)),axis=1)

df2['sparkline_example'] = df2.apply(lambda x: 'Jan-18:500, Feb-18:600, Mar-18:800',axis=1)
# df2 = df2[['name','name_url','owner_url','links','description','ico_start_date','ico_end_date','ico_sold_status','sparkline_example','Total_Score','twitter_followers','facebook_followers','hype_score','risk_score','symbol']]
df2.sort_values(by=['ico_end_date'])
# df2.columns = ['ICO Name','Founder','Links','Description','Start Date','End Date','Status','Price History']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-e0810620b2a4> in <module>()
#      30 df2['name_url'] = df2.apply(lambda x: str(x['name']) + '|' + '/detail/' + x['name'],axis=1)
#      31 df2['owner_url'] = df2.apply(lambda x: owner_url(x),axis=1)
# ---> 32 df2['links'] = df2.apply(lambda x: make_link(get_links(x)),axis=1)
#      33
#      34 df2['sparkline_example'] = df2.apply(lambda x: 'Jan-18:500, Feb-18:600, Mar-18:800',axis=1)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-69-e0810620b2a4> in <lambda>(x)
#      30 df2['name_url'] = df2.apply(lambda x: str(x['name']) + '|' + '/detail/' + x['name'],axis=1)
#      31 df2['owner_url'] = df2.apply(lambda x: owner_url(x),axis=1)
# ---> 32 df2['links'] = df2.apply(lambda x: make_link(get_links(x)),axis=1)
#      33
#      34 df2['sparkline_example'] = df2.apply(lambda x: 'Jan-18:500, Feb-18:600, Mar-18:800',axis=1)
#
# <ipython-input-69-e0810620b2a4> in get_links(row)
#      13     if len(row['company_url']) > 1:
#      14         links.append({'label': 'URL', 'url': row['company_url']})
# ---> 15     if len(row['whitepaper']) > 1:
#      16         links.append({'label': 'Whitepaper', 'url': row['whitepaper']})
#      17     # parse social dict
#
# TypeError: ("object of type 'float' has no len()", 'occurred at index 545')

# %%
[x['links'] for x in df2.to_dict(orient='records')][0]

# %%
df2[df2['owner_url'] == 'Minh Lee']
# Out:
#          ICO_JOIN_KEY                     _id_x      base  \
# 116  hedgecoincapital  5b1c912b48d6215496c4d4e5  Ethereum
#
#                     bonus_details  cluster_pca  \
# 116  Start Bonus: 25% - Raised: 0          NaN
#
#                            company_url                         description  \
# 116  https://ico.hedgecoincapital.com/  An Australian-based cryptocurrency
#
#        escrow_class escrow_href                             ico_dates  \
# 116  [fa, fa-close]         NaN  01/03/2018 00:00:00 UTC - 03/06/2018
#
#                         ico_sold_status                 name  \
# 116  ICO: 70,000,000 HCL of 136,000,000  Hedge Coin Capital
#
#     owner_linkedin_profile owner_name  \
# 116                    NaN   Minh Lee
#
#                                                 social     status  \
# 116  {'Telegram': 'https://t.me/hedgecoincapital', ...  no_reddit
#
#                                            tracker_url  \
# 116  https://icotracker.net/project/hedge_coin_capi...
#
#                                             whitepaper   ico_start_datetime  \
# 116  https://ico.hedgecoincapital.com/wp-content/up...  2018-03-01 00:00:00
#
#     ico_end_datetime ico_start_date ico_end_date ICO_x  Total_Score  \
# 116       2018-06-03     01/03/2018   03/06/2018   NaN          NaN
#
#     twitter_followers facebook_followers symbol HYPE SCORE  HYPE_CODE_BINARY  \
# 116               NaN                NaN    HCL        NaN               NaN
#
#     RISK SCORE  RISK_CODE _id_y risk_score hype_score ICO_y  \
# 116        NaN        NaN   NaN        LOW        LOW   NaN
#
#      RISK_CODE_TERTIARY  HYPE_CODE_TERTIARY  Stanford_Sentiment_Score_Proc  \
# 116                 NaN                 NaN                            NaN
#
#     sentiment_score EXG_PRICE_RATING  pch7  \
# 116        NEGATIVE             HIGH   NaN
#
#                                             name_url owner_url  \
# 116  Hedge Coin Capital |/detail/Hedge Coin Capital   Minh Lee
#
#                                                  links  \
# 116  <a href='https://ico.hedgecoincapital.com/'>UR...
#
#                       sparkline_example
# 116  Jan-18:500, Feb-18:600, Mar-18:800

# %% [markdown]
# ### Write to Collection

# %%
db.db['sp_upcoming_summary_v2'].delete_many({})
db.db['sp_upcoming_summary_v2'].insert_many(df2.to_dict('records'))

# %%
df1 = db.toDF('sp_upcoming_summary_v2')
print(df1.columns)

# %%
df2['pch7'].drop_duplicates()

# %%
prices = db.toDF('reddit_summary')
prices.head()

# %%
pd.merge(df1,prices,how='inner',left_on='name',right_on='ICO').groupby(['symbol']).agg('count')

# %%
upcoming = df1['name'].tolist()

# %%
x = db.toDF('sp_upcoming_summary')
x.head()

# %%
upcoming.sort()
upcoming

# %%
reddits = x['ICO'].tolist()
reddits.sort()
reddits

# %%
db.db.collection_names()
