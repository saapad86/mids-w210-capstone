# %%
Use these details to connect
    user: w210_db_user
    pwd: q1w2e3r4$
    server: 198.11.212.212
    authenticationDatabase: w210_db

# %%
# Install PyMongo
# !conda install pymongo -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/spadela/miniconda3
#
#   added / updated specs:
#     - pymongo
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pymongo-3.4.0              |           py36_0         411 KB
#
# The following NEW packages will be INSTALLED:
#
#     pymongo: 3.4.0-py36_0
#
#
# Downloading and Extracting Packages
# pymongo-3.4.0        |  411 KB | ####################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import urllib.parse
from pymongo import MongoClient

username = urllib.parse.quote_plus('w210_db_user')
password = urllib.parse.quote_plus('q1w2e3r4$')
conn = MongoClient('mongodb://%s:%s@198.11.212.212:27017/w210_db' % (username, password))
db = conn.w210_db

# %%
db
# Out:
# Database(MongoClient(host=['198.11.212.212:27017'], document_class=dict, tz_aware=False, connect=True), 'w210_db')

# %%
coll = db["icotracker_ico"]
result = coll.find({})

# %%
import pandas as pd

data = []
for i,row in enumerate(result):
    data.append(row)
    if i > 5:
        break
pd.DataFrame(data)
# Out:
#                         _id      base                  bonus_details  \
# 0  5b1c8cf448d6215496c4d2c0  Ethereum   Start Bonus: 35% - Raised: 0
# 1  5b1c8cf448d6215496c4d2c1  Ethereum   Start Bonus: 30% - Raised: 0
# 2  5b1c8cf548d6215496c4d2c2  Ethereum   Start Bonus: 25% - Raised: 0
# 3  5b1c8ef048d6215496c4d2c4  Ethereum   Start Bonus: 50% - Raised: 0
# 4  5b1c8ef048d6215496c4d2c5     Waves   Start Bonus: 50% - Raised: 0
# 5  5b1c8f2148d6215496c4d2c6  Ethereum  Start Bonus: 100% - Raised: 0
# 6  5b1c8f2148d6215496c4d2c7  Ethereum   Start Bonus: 10% - Raised: 0
#
#                              company_url  \
# 0                 https://patron-ico.io/
# 1                     http://crypton.vc/
# 2  https://www.sosrcoin.io/en/index.html
# 3                   https://dynatiq.com/
# 4                  https://3ccoin.io/en/
# 5         https://tokensale-squader.com/
# 6     https://www.smarterthancrypto.com/
#
#                                          description    escrow_class  \
# 0  A decentralized platform which shares economie...  [fa, fa-close]
# 1  A Blockchain-based cryptocurrency venture capi...  [fa, fa-close]
# 2  A cryptocurrency focusing on solving waste pro...  [fa, fa-close]
# 3  A Blockchain-based marketplace for domains and...  [fa, fa-close]
# 4  A Blockchain-based option to invest in the pro...  [fa, fa-close]
# 5  A payment token for premium features in the ap...  [fa, fa-close]
# 6          A cryptocurrency-only tokenized portfolio  [fa, fa-close]
#
#                               ico_dates  \
# 0  09/05/2018 00:00:00 UTC - 09/06/2018
# 1  29/03/2018 00:00:00 UTC - 09/06/2018
# 2  10/04/2018 00:00:00 UTC - 09/06/2018
# 3  25/04/2018 00:00:00 UTC - 09/06/2018
# 4  10/05/2018 00:00:00 UTC - 10/06/2018
# 5  29/04/2018 00:00:00 UTC - 10/06/2018
# 6  13/05/2018 08:00:00 UTC - 10/06/2018
#
#                            ico_sold_status                       name  \
# 0      ICO: 240,000,000 PAT of 400,000,000                     PATRON
# 1        ICO: 50,400,000 CRN of 72,000,000                 Crypton VC
# 2       ICO: 45,000,000 SOSR of 50,000,000                       SOSR
# 3        ICO: 10,000,000 DTQ of 11,000,000                    Dynatiq
# 4                          ICO: ~ 3cCoin ~                     3cCoin
# 5  ICO: 8,000,000,000 SQC of 8,000,000,000         Squader Token Sale
# 6       ICO: 87,000,000 STC of 100,000,000  Smarter Than Crypto (ICO)
#
#                               owner_linkedin_profile         owner_name  \
# 0     https://www.linkedin.com/in/atsushi-hisatsumi/  Atsushi Hisatsumi
# 1           https://www.linkedin.com/in/jaceknowak2/        Jacek Nowak
# 2  https://icotracker.net/www.linkedin.com/in/cha...           Zhen Lin
# 3             https://www.linkedin.com/in/abdaluzza/        Abd al Uzza
# 4               https://www.facebook.com/asb-service     Alexey Butorin
# 5                                                NaN                  -
# 6                                                NaN       Oliver Prock
#
#                                               social     status  \
# 0  {'Telegram': 'https://t.me/patronicoen', 'Face...  no_reddit
# 1  {'Github': 'https://github.com/CryptonVC', 'Te...  no_reddit
# 2              {'Telegram': 'https://t.me/sosrcoin'}  no_reddit
# 3  {'Blog': 'https://medium.com/@dynatiq', 'Teleg...  no_reddit
# 4  {'Youtube': 'https://www.youtube.com/channel/U...  no_reddit
# 5  {'Blog': 'https://medium.com/@squadcoin', 'Tel...  no_reddit
# 6  {'Reddit': 'https://www.reddit.com/user/Smarte...   not_a_sr
#
#                                          tracker_url  \
# 0              https://icotracker.net/project/patron
# 1          https://icotracker.net/project/crypton_vc
# 2                https://icotracker.net/project/sosr
# 3             https://icotracker.net/project/dynatiq
# 4              https://icotracker.net/project/3ccoin
# 5  https://icotracker.net/project/squader_token_sale
# 6  https://icotracker.net/project/smarter_than_cr...
#
#                                           whitepaper
# 0  https://patron-ico.io/doc/patron-wp-en-01-2018...
# 1     http://crypton.vc/assets/files/white-paper.pdf
# 2  https://drive.google.com/file/d/1jHYIt6TZm3ZTB...
# 3                 https://dynatiq.com/whitepaper.pdf
# 4  https://3ccoin.io/download/en/3cCoin_crowdsale...
# 5  https://tokensale-squader.com/docs/Squadcoin-w...
# 6  https://www.smarterthancrypto.com/doc/Smarter_...

# %%
deadcoin = db["deadcoin_ico"]
result = deadcoin.find({})

# %%
data = []
for i,row in enumerate(result):
    data.append(row)
pd.DataFrame(data)
# Out:
#                           _id  \
# 0    5b22206f48d621122074eb16
# 1    5b22206f48d621122074eb17
# 2    5b22206f48d621122074eb18
# 3    5b22206f48d621122074eb19
# 4    5b22206f48d621122074eb1a
# 5    5b22206f48d621122074eb1b
# 6    5b22206f48d621122074eb1c
# 7    5b22206f48d621122074eb1d
# 8    5b22206f48d621122074eb1e
# 9    5b22206f48d621122074eb1f
# 10   5b22206f48d621122074eb20
# 11   5b22206f48d621122074eb21
# 12   5b22206f48d621122074eb22
# 13   5b22206f48d621122074eb23
# 14   5b22206f48d621122074eb24
# 15   5b22206f48d621122074eb25
# 16   5b22206f48d621122074eb26
# 17   5b22206f48d621122074eb27
# 18   5b22206f48d621122074eb28
# 19   5b22206f48d621122074eb29
# 20   5b22206f48d621122074eb2a
# 21   5b22206f48d621122074eb2b
# 22   5b22206f48d621122074eb2c
# 23   5b22206f48d621122074eb2d
# 24   5b22206f48d621122074eb2e
# 25   5b22206f48d621122074eb2f
# 26   5b22206f48d621122074eb30
# 27   5b22206f48d621122074eb31
# 28   5b22206f48d621122074eb32
# 29   5b22206f48d621122074eb33
# ..                        ...
# 775  5b22209548d621122074ee1d
# 776  5b22209548d621122074ee1e
# 777  5b22209548d621122074ee1f
# 778  5b22209548d621122074ee20
# 779  5b22209548d621122074ee21
# 780  5b22209548d621122074ee22
# 781  5b22209548d621122074ee23
# 782  5b22209548d621122074ee24
# 783  5b22209548d621122074ee25
# 784  5b22209548d621122074ee26
# 785  5b22209548d621122074ee27
# 786  5b22209648d621122074ee28
# 787  5b22209648d621122074ee29
# 788  5b22209648d621122074ee2a
# 789  5b22209648d621122074ee2b
# 790  5b22209648d621122074ee2c
# 791  5b22209648d621122074ee2d
# 792  5b22209648d621122074ee2e
# 793  5b22209648d621122074ee2f
# 794  5b22209648d621122074ee30
# 795  5b22209648d621122074ee31
# 796  5b22209648d621122074ee32
# 797  5b22209648d621122074ee33
# 798  5b22209648d621122074ee34
# 799  5b22209648d621122074ee35
# 800  5b22209648d621122074ee36
# 801  5b22209648d621122074ee37
# 802  5b22209648d621122074ee38
# 803  5b22209648d621122074ee39
# 804  5b22209648d621122074ee3a
#
#                                                comment                   name  \
# 0                                 created via Coingen.         HackerNewsCoin
# 1                                                               FourtyTwoCoin
# 2                                                                Dollarpounds
# 3                                                                CryptoApples
# 4                                  Created via coingen            CollegeCoin
# 5                  So good these guys picked it twice!               Coincoin
# 6    Observed trading 12 July 2014 at market cap $6...               Cococoin
# 7                                                                    Catedoge
# 8                                                       Brokebackmountaincoin
# 9                                                                  Boringcoin
# 10   I created it and it was stolen. I have blocked...          Superior Coin
# 11   Launched Dec 27 2013.  The client was malware;...            YinYuanCoin
# 12   Thecoin was malware; the wallet contained a ke...                Thecoin
# 13   Launched Feb 21 2014.  The client was malware;...               Oreocoin
# 14   Launched Jan 13 2014.  The client was malware;...             JunnonCoin
# 15   Launched Feb 12 2014.  The client was malware;...             Chichicoin
# 16   Very shitty coin. Owner of the coin buyed fake...               MintCoin
# 17   It lasted from october to december 2017. The c...           Bigboobscoin
# 18            Because Bitcoin and Bytecoin were taken.               BiteCoin
# 19   Started trading March 29 2014 and appears to h...              Blitzcoin
# 20                                                                  Onioncoin
# 21                                                                  QuackCoin
# 22                                                                Secondscoin
# 23                                       A fork of NXT                   Stop
# 24                                                                  Unitycoin
# 25      Observed with market cap $1213 on 13 June 2014                XXLcoin
# 26                                                                    Phicoin
# 27                                                                 Rocketcoin
# 28                                  died 29 April 2014              SlothCoin
# 29   Only ten of these coins ever existed. Then onl...            TenFiveCoin
# ..                                                 ...                    ...
# 775                                         Lost data!            ConcardCoin
# 776                                It had a sick logo.              Darkshibe
# 777  After ICO was over, twitter, website and all c...               RedChain
# 778  ICO stopped. Website gone. Got away with 2.3 M...       Endtimes Network
# 779  Found on Bitcointalk. Upcoming ICO. Zero techn...               ConnectX
# 780  SCAM.  Supposed to revolutionize the way we pa...                 Bitair
# 781  Scammers collected ETH in an ICO and simply va...                Kencoin
# 782  1. Same team member which involved in Bitcoin ...          Ethereum Vega
# 783  https://bitcointalk.org/index.php?topic=208776...         SURECOIN (TSC)
# 784  Aimed to "decentralize the seed market using b...                TimCoin
# 785                      A scam coin made by a scammer               Britcoin
# 786  This was a crowdsale of shares by Mycelium Wal...                     MT
# 787  ICO meant to back hardware miners, ICO was nev...             Cleverhash
# 788  Promoted by YouTubers, creator doxxed by LEGEN...            ElektraCoin
# 789  i bought into the ico but the coin was never l...         RasputinOnline
# 790  Huge P&D by the creators. Dripped ETHD every w...          Ethereum Dark
# 791                                    this is SCAMMMM           bitbase coin
# 792  After the release, they dumped the coin by sel...           Infinity pay
# 793                                               scam               AiOtoken
# 794  scam coin allegedly based on urea mineral markets                Urocoin
# 795  LOOKS LIKE A BIG SCAM LISTED IN YOBIT AND LIVE...              firstcoin
# 796  The developers released cloned Codecanyon game...                1CRedit
# 797   it is a fraud coin ,run by amit bhardwaj scammer                   mcap
# 798       It was never really alive in the first place               Snatcoin
# 799  Scam coin ICO with plagiarized white paper.  A...            Eros Vision
# 800  PROVEN TO BE A SCAM COINhttps://www.reddit.com...            ParagonCoin
# 801  Franko is a shitcoin LTC clone I made to scam ...                 Franko
# 802                                Created via coingen            CollegeCoin
# 803                                                              CryptoApples
# 804                                                              Dollarpounds
#
#          rating    status                 url
# 0    0.0 rating    Parody
# 1    0.0 rating    Parody
# 2    0.0 rating    Parody
# 3    0.0 rating    Parody
# 4    0.0 rating    Parody
# 5    0.0 rating    Parody
# 6    0.0 rating    Parody
# 7    0.0 rating    Parody
# 8    0.0 rating    Parody
# 9    0.0 rating    Parody
# 10   0.0 rating      Hack
# 11   0.0 rating      Hack
# 12   0.0 rating      Hack
# 13   0.0 rating      Hack
# 14   0.0 rating      Hack
# 15   0.0 rating      Hack
# 16   0.0 rating  Deceased   coinmarketcap.com
# 17   0.0 rating  Deceased   coinmarketcap.com
# 18   0.0 rating  Deceased
# 19   0.0 rating  Deceased
# 20   0.0 rating  Deceased
# 21   0.0 rating  Deceased
# 22   0.0 rating  Deceased
# 23   0.0 rating  Deceased
# 24   0.0 rating  Deceased
# 25   0.0 rating  Deceased
# 26   0.0 rating  Deceased
# 27   0.0 rating  Deceased
# 28   0.0 rating  Deceased
# 29   0.0 rating  Deceased
# ..          ...       ...                 ...
# 775  0.0 rating  Deceased      concardcoin.io
# 776  0.0 rating  Deceased     bitcointalk.org
# 777  0.0 rating      Scam      icotracker.net
# 778  0.0 rating      Scam         endtimes.io
# 779  0.0 rating      Scam        connectx.com
# 780  0.0 rating      Scam           bitair.io
# 781  0.0 rating      Scam
# 782  0.0 rating      Scam          github.com
# 783  0.0 rating      Scam     bitcointalk.org
# 784  0.0 rating      Scam      freeforums.net
# 785  0.0 rating      Scam   coinmarketcap.com
# 786  0.0 rating      Scam        mycelium.com
# 787  0.0 rating      Scam   coinmarketcap.com
# 788  0.0 rating      Scam
# 789  0.0 rating      Scam  rasputinonline.com
# 790  0.0 rating      Scam   coinmarketcap.com
# 791  0.0 rating      Scam          bitbase.io
# 792  0.0 rating      Scam
# 793  0.0 rating      Scam         aio.network
# 794  0.0 rating      Scam
# 795  0.0 rating      Scam      firstcoin.club
# 796  0.0 rating      Scam   coinmarketcap.com
# 797  0.0 rating      Scam   coinmarketcap.com
# 798  0.0 rating      Scam        snatcoin.com
# 799  0.0 rating      Scam          reddit.com
# 800  0.0 rating      Scam     paragoncoin.com
# 801  0.0 rating      Scam   coinmarketcap.com
# 802  0.0 rating    Parody
# 803  0.0 rating    Parody
# 804  0.0 rating    Parody
#
# [805 rows x 6 columns]
