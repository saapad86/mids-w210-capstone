# %%
import requests
import pandas as pd
import numpy as np
from datetime import datetime

### Set Up Mongo Connection

import time
import urllib.parse
from pymongo import MongoClient

username = urllib.parse.quote_plus('w210_db_user')
password = urllib.parse.quote_plus('q1w2e3r4$')
conn = MongoClient('mongodb://%s:%s@198.11.212.212:27017/w210_db' % (username, password))
db = conn.w210_db

pd.set_option('display.max_columns', 500)

# %%
result = db['sp_overlap_analysis'].find({'ind_cryptocompare': 1})

data = []
for i,row in enumerate(result):
    data.append(row)
    
master = pd.DataFrame(data)
print('Found %d records' % len(master))
master.head()
# Out:
# Found 453 records
#                         _id  ico_phase_ended  ind_coinmarketcap  \
# 0  5b40605c57c41002aa12d99a                1                  1
# 1  5b40605c57c41002aa12d9a3                1                  0
# 2  5b40605c57c41002aa12d9cc                1                  0
# 3  5b40605c57c41002aa12d9e1                1                  0
# 4  5b40605c57c41002aa12d9e4                1                  0
#
#    ind_cryptocompare  ind_cryptowatch  ind_ravneeticoprice               name
# 0                  1                1                    0             PATRON
# 1                  1                0                    0  Sentinel Protocol
# 2                  1                0                    0      LocalCoinSwap
# 3                  1                0                    0          VideoCoin
# 4                  1                0                    0             Befund

# %%
result = db['sp_price_history'].find({})

price_history = []
for i,row in enumerate(result):
    price_history.append(row)
    
price_history[:2]
# Out:
# [{'_id': ObjectId('5b40625e57c41009c0b56bdc'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-03-29',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bdd'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-03-30',
#   'price': 0}]

# %%
api_url = 'https://min-api.cryptocompare.com/data/histoday?fsym={symbol}&tsym=USD&limit=100'
for i,row in enumerate(master.to_dict(orient='records')):
    name = row['name']
    # Skip if we already have pricing data
    if name in [x['name'] for x in price_history]:
        print('Found existing pricing data for {name}. Skipping...'.format(name=name))
        continue
    try:
        # Look up symbol
        symbol = db['sp_cryptocompare'].find_one({'CoinName': name})['Symbol']
        # Get price data from CryptoCompare
        print('Getting Price Data from CryptoCompare for {name} - {symbol} ({i} of {length})'.format \
              (name=name,symbol=symbol,i=i+1,length=len(master)))
        response = requests.get(api_url.format(symbol=symbol))

        print('Writing records to db...')
        db.sp_price_history.delete_many({'symbol': symbol, 'source': 'CryptoCompare'})
        for r in response.json()['Data']:
            d = {
                'name': name,
                'symbol': symbol,
                'close_date' : datetime.strftime(datetime.fromtimestamp(r['time']),'%Y-%m-%d'),
                'price': float(r['close']),
                'source': 'CryptoCompare'
            }
            if d['price'] > 0:
                db.sp_price_history.insert_one(d)
    except:
        # Fail silently...
        pass
    time.sleep(2)
# Out:
# Found existing pricing data for PATRON. Skipping...
# Found existing pricing data for Sentinel Protocol. Skipping...
# Getting Price Data from CryptoCompare for LocalCoinSwap - LCS (3 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for VideoCoin - VID (4 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Befund - BFDT (5 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Slate - SLX (6 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Chimaera - CHI (7 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Utrum - OOT (8 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Acorn Collective - OAK (9 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for VLUX - VLUX (10 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Tradelize - TDZ (11 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Market.space - MASP (13 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Triwer - TRW (15 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Bettium - BETT (16 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Curaizon - CTKN (17 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Verasity - VRA (18 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Tutellus - TUT (19 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Pavocoin - PAVO (20 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for ZeroState - ZSC* (21 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Loyakk Vega - LYK (22 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for GreenX - GEX (23 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Ubex - UBEX (24 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for FlipNpik - FNP (26 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Crowd Machine - CMCT (28 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for AI Crypto - AIC (30 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Blockchain Traded Fund - BTF (31 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for EOS - EOS (32 of 453)
# Writing records to db...
# Getting Price Data from CryptoCompare for Cool Cousin - CUZ (33 of 453)
# Writing records to db...

# %%
result = db['sp_price_history'].find({})

data = []
for i,row in enumerate(result):
    data.append(row)
    
data
# Out:
# [{'_id': ObjectId('5b40625e57c41009c0b56bdc'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-03-29',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bdd'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-03-30',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bde'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-03-31',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bdf'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-01',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be0'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-02',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be1'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-03',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be2'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-04',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be3'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-05',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be4'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-06',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be5'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-07',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be6'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-08',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be7'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-09',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be8'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-10',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56be9'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-11',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bea'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-12',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56beb'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-13',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bec'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-14',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bed'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-15',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bee'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-16',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bef'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-17',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf0'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-18',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf1'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-19',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf2'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-20',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf3'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-21',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf4'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-22',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf5'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-23',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf6'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-24',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf7'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-25',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf8'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-26',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bf9'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-27',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bfa'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-28',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bfb'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-29',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bfc'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-30',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bfd'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-01',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bfe'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-02',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56bff'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-03',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c00'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-04',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c01'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-05',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c02'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-06',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c03'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-07',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c04'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-08',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c05'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-09',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c06'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-10',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c07'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-11',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c08'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-12',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c09'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-13',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c0a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-14',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c0b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-15',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c0c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-16',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c0d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-17',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c0e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-18',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c0f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-19',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c10'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-20',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c11'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-21',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c12'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-22',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c13'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-23',
#   'price': 0},
#  {'_id': ObjectId('5b40625e57c41009c0b56c14'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-24',
#   'price': 0.06267},
#  {'_id': ObjectId('5b40625e57c41009c0b56c15'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-25',
#   'price': 0.05906},
#  {'_id': ObjectId('5b40625e57c41009c0b56c16'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-26',
#   'price': 0.05155},
#  {'_id': ObjectId('5b40625e57c41009c0b56c17'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-27',
#   'price': 0.1304},
#  {'_id': ObjectId('5b40625e57c41009c0b56c18'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-28',
#   'price': 0.09473},
#  {'_id': ObjectId('5b40625e57c41009c0b56c19'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-29',
#   'price': 0.08329},
#  {'_id': ObjectId('5b40625e57c41009c0b56c1a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-30',
#   'price': 0.06908},
#  {'_id': ObjectId('5b40625e57c41009c0b56c1b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-31',
#   'price': 0.07562},
#  {'_id': ObjectId('5b40625e57c41009c0b56c1c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-01',
#   'price': 0.07411},
#  {'_id': ObjectId('5b40625e57c41009c0b56c1d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-02',
#   'price': 0.0685},
#  {'_id': ObjectId('5b40625e57c41009c0b56c1e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-03',
#   'price': 0.06562},
#  {'_id': ObjectId('5b40625e57c41009c0b56c1f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-04',
#   'price': 0.0473},
#  {'_id': ObjectId('5b40625e57c41009c0b56c20'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-05',
#   'price': 0.05292},
#  {'_id': ObjectId('5b40625e57c41009c0b56c21'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-06',
#   'price': 0.05214},
#  {'_id': ObjectId('5b40625e57c41009c0b56c22'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-07',
#   'price': 0.04956},
#  {'_id': ObjectId('5b40625e57c41009c0b56c23'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-08',
#   'price': 0.04916},
#  {'_id': ObjectId('5b40625e57c41009c0b56c24'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-09',
#   'price': 0.05044},
#  {'_id': ObjectId('5b40625e57c41009c0b56c25'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-10',
#   'price': 0.04093},
#  {'_id': ObjectId('5b40625e57c41009c0b56c26'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-11',
#   'price': 0.04302},
#  {'_id': ObjectId('5b40625e57c41009c0b56c27'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-12',
#   'price': 0.03758},
#  {'_id': ObjectId('5b40625e57c41009c0b56c28'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-13',
#   'price': 0.03286},
#  {'_id': ObjectId('5b40625e57c41009c0b56c29'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-14',
#   'price': 0.03171},
#  {'_id': ObjectId('5b40625e57c41009c0b56c2a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-15',
#   'price': 0.03071},
#  {'_id': ObjectId('5b40625e57c41009c0b56c2b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-16',
#   'price': 0.03132},
#  {'_id': ObjectId('5b40625e57c41009c0b56c2c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-17',
#   'price': 0.03378},
#  {'_id': ObjectId('5b40625e57c41009c0b56c2d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-18',
#   'price': 0.03779},
#  {'_id': ObjectId('5b40625e57c41009c0b56c2e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-19',
#   'price': 0.04092},
#  {'_id': ObjectId('5b40625e57c41009c0b56c2f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-20',
#   'price': 0.04397},
#  {'_id': ObjectId('5b40625e57c41009c0b56c30'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-21',
#   'price': 0.03943},
#  {'_id': ObjectId('5b40625e57c41009c0b56c31'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-22',
#   'price': 0.02681},
#  {'_id': ObjectId('5b40625e57c41009c0b56c32'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-23',
#   'price': 0.03319},
#  {'_id': ObjectId('5b40625e57c41009c0b56c33'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-24',
#   'price': 0.02914},
#  {'_id': ObjectId('5b40625e57c41009c0b56c34'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-25',
#   'price': 0.0312},
#  {'_id': ObjectId('5b40625e57c41009c0b56c35'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-26',
#   'price': 0.03093},
#  {'_id': ObjectId('5b40625e57c41009c0b56c36'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-27',
#   'price': 0.0296},
#  {'_id': ObjectId('5b40625e57c41009c0b56c37'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-28',
#   'price': 0.02651},
#  {'_id': ObjectId('5b40625e57c41009c0b56c38'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-29',
#   'price': 0.0296},
#  {'_id': ObjectId('5b40625e57c41009c0b56c39'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-30',
#   'price': 0.02947},
#  {'_id': ObjectId('5b40625e57c41009c0b56c3a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-01',
#   'price': 0.03299},
#  {'_id': ObjectId('5b40625e57c41009c0b56c3b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-02',
#   'price': 0.03574},
#  {'_id': ObjectId('5b40625e57c41009c0b56c3c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-03',
#   'price': 0.03372},
#  {'_id': ObjectId('5b40625e57c41009c0b56c3d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-04',
#   'price': 0.0285},
#  {'_id': ObjectId('5b40625e57c41009c0b56c3e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-05',
#   'price': 0.02572},
#  {'_id': ObjectId('5b40625e57c41009c0b56c3f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-06',
#   'price': 0.02726},
#  {'_id': ObjectId('5b40625e57c41009c0b56c40'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-07',
#   'price': 0.02812},
#  {'_id': ObjectId('5b40626e57c41009c0b56c41'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-03-29',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c42'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-03-30',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c43'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-03-31',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c44'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-01',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c45'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-02',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c46'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-03',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c47'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-04',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c48'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-05',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c49'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-06',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c4a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-07',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c4b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-08',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c4c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-09',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c4d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-10',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c4e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-11',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c4f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-12',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c50'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-13',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c51'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-14',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c52'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-15',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c53'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-16',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c54'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-17',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c55'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-18',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c56'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-19',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c57'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-20',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c58'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-21',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c59'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-22',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c5a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-23',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c5b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-24',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c5c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-25',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c5d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-26',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c5e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-27',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c5f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-28',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c60'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-29',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c61'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-04-30',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c62'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-01',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c63'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-02',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c64'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-03',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c65'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-04',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c66'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-05',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c67'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-06',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c68'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-07',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c69'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-08',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c6a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-09',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c6b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-10',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c6c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-11',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c6d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-12',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c6e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-13',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c6f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-14',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c70'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-15',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c71'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-16',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c72'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-17',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c73'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-18',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c74'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-19',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c75'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-20',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c76'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-21',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c77'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-22',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c78'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-23',
#   'price': 0},
#  {'_id': ObjectId('5b40626e57c41009c0b56c79'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-24',
#   'price': 0.06267},
#  {'_id': ObjectId('5b40626e57c41009c0b56c7a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-25',
#   'price': 0.05906},
#  {'_id': ObjectId('5b40626e57c41009c0b56c7b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-26',
#   'price': 0.05155},
#  {'_id': ObjectId('5b40626e57c41009c0b56c7c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-27',
#   'price': 0.1304},
#  {'_id': ObjectId('5b40626e57c41009c0b56c7d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-28',
#   'price': 0.09473},
#  {'_id': ObjectId('5b40626e57c41009c0b56c7e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-29',
#   'price': 0.08329},
#  {'_id': ObjectId('5b40626e57c41009c0b56c7f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-30',
#   'price': 0.06908},
#  {'_id': ObjectId('5b40626e57c41009c0b56c80'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-05-31',
#   'price': 0.07562},
#  {'_id': ObjectId('5b40626e57c41009c0b56c81'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-01',
#   'price': 0.07411},
#  {'_id': ObjectId('5b40626e57c41009c0b56c82'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-02',
#   'price': 0.0685},
#  {'_id': ObjectId('5b40626e57c41009c0b56c83'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-03',
#   'price': 0.06562},
#  {'_id': ObjectId('5b40626e57c41009c0b56c84'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-04',
#   'price': 0.0473},
#  {'_id': ObjectId('5b40626e57c41009c0b56c85'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-05',
#   'price': 0.05292},
#  {'_id': ObjectId('5b40626e57c41009c0b56c86'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-06',
#   'price': 0.05214},
#  {'_id': ObjectId('5b40626e57c41009c0b56c87'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-07',
#   'price': 0.04956},
#  {'_id': ObjectId('5b40626e57c41009c0b56c88'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-08',
#   'price': 0.04916},
#  {'_id': ObjectId('5b40626e57c41009c0b56c89'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-09',
#   'price': 0.05044},
#  {'_id': ObjectId('5b40626e57c41009c0b56c8a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-10',
#   'price': 0.04093},
#  {'_id': ObjectId('5b40626e57c41009c0b56c8b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-11',
#   'price': 0.04302},
#  {'_id': ObjectId('5b40626e57c41009c0b56c8c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-12',
#   'price': 0.03758},
#  {'_id': ObjectId('5b40626e57c41009c0b56c8d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-13',
#   'price': 0.03286},
#  {'_id': ObjectId('5b40626e57c41009c0b56c8e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-14',
#   'price': 0.03171},
#  {'_id': ObjectId('5b40626e57c41009c0b56c8f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-15',
#   'price': 0.03071},
#  {'_id': ObjectId('5b40626e57c41009c0b56c90'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-16',
#   'price': 0.03132},
#  {'_id': ObjectId('5b40626e57c41009c0b56c91'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-17',
#   'price': 0.03378},
#  {'_id': ObjectId('5b40626e57c41009c0b56c92'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-18',
#   'price': 0.03779},
#  {'_id': ObjectId('5b40626e57c41009c0b56c93'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-19',
#   'price': 0.04092},
#  {'_id': ObjectId('5b40626e57c41009c0b56c94'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-20',
#   'price': 0.04397},
#  {'_id': ObjectId('5b40626e57c41009c0b56c95'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-21',
#   'price': 0.03943},
#  {'_id': ObjectId('5b40626e57c41009c0b56c96'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-22',
#   'price': 0.02681},
#  {'_id': ObjectId('5b40626e57c41009c0b56c97'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-23',
#   'price': 0.03319},
#  {'_id': ObjectId('5b40626e57c41009c0b56c98'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-24',
#   'price': 0.02914},
#  {'_id': ObjectId('5b40626e57c41009c0b56c99'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-25',
#   'price': 0.0312},
#  {'_id': ObjectId('5b40626e57c41009c0b56c9a'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-26',
#   'price': 0.03093},
#  {'_id': ObjectId('5b40626e57c41009c0b56c9b'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-27',
#   'price': 0.0296},
#  {'_id': ObjectId('5b40626e57c41009c0b56c9c'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-28',
#   'price': 0.02651},
#  {'_id': ObjectId('5b40626e57c41009c0b56c9d'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-29',
#   'price': 0.0296},
#  {'_id': ObjectId('5b40626e57c41009c0b56c9e'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-06-30',
#   'price': 0.02947},
#  {'_id': ObjectId('5b40626e57c41009c0b56c9f'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-01',
#   'price': 0.03299},
#  {'_id': ObjectId('5b40626e57c41009c0b56ca0'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-02',
#   'price': 0.03574},
#  {'_id': ObjectId('5b40626e57c41009c0b56ca1'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-03',
#   'price': 0.03372},
#  {'_id': ObjectId('5b40626e57c41009c0b56ca2'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-04',
#   'price': 0.0285},
#  {'_id': ObjectId('5b40626e57c41009c0b56ca3'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-05',
#   'price': 0.02572},
#  {'_id': ObjectId('5b40626e57c41009c0b56ca4'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-06',
#   'price': 0.02726},
#  {'_id': ObjectId('5b40626e57c41009c0b56ca5'),
#   'name': 'PATRON',
#   'symbol': 'PAT',
#   'close_date': '2018-07-07',
#   'price': 0.02812}]

# %%
datetime.strftime(datetime.fromtimestamp(1522281600),'%Y-%m-%d')
# Out:
# '2018-03-29'

# %%
import datetime
datetime.datetime.strftime(datetime.datetime.fromtimestamp(1522886400),'%Y-%m-%d')
# Out:
# '2018-04-05'
