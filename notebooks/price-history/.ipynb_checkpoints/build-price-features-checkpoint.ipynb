# %%
import os
import sys
paths = {
    'helpers': '/home/spadela/mids-w210-capstone'
}
for k,v in paths.items():
    sys.path.insert(0, v)
    
import requests
import pandas as pd
import numpy as np
import datetime
from copy import deepcopy

from bs4 import BeautifulSoup

### Set Up Mongo Connection
from db import dbToolsMongo
db = dbToolsMongo()

import time
import urllib.parse

pd.set_option('display.max_columns', 500)

# %reload_ext autoreload
# %autoreload 2

# %%
# Delete all records with price = 0 or source = null
db.db.sp_price_history.delete_many({"price": {"$lte": 0.0}})
db.db.sp_price_history.delete_many({"source": None})

df1 = db.toDF('sp_price_history')
df1['close_date'] = df1['close_date'].apply(lambda x: datetime.datetime.strptime(x,'%Y-%m-%d'))
df1 = df1.drop_duplicates(subset=['name','close_date'])
df1.sort_values(by=['name','close_date']).head()
# Out:
#                            _id close_date      name    price         source  \
# 6148  5b4278f057c41009c0b628e8 2018-05-24  AB-CHAIN  0.05845  CryptoCompare
# 6149  5b4278f057c41009c0b628e9 2018-05-25  AB-CHAIN  0.07280  CryptoCompare
# 6150  5b4278f057c41009c0b628ea 2018-05-26  AB-CHAIN  0.07287  CryptoCompare
# 6151  5b4278f057c41009c0b628eb 2018-05-27  AB-CHAIN  0.07206  CryptoCompare
# 6152  5b4278f057c41009c0b628ec 2018-05-28  AB-CHAIN  0.05735  CryptoCompare
#
#      symbol
# 6148    RTB
# 6149    RTB
# 6150    RTB
# 6151    RTB
# 6152    RTB

# %%
x = db.toDF('sp_price_history',filters={'name': 'EOS'}).sort_values(by='close_date')
x.head()
# Out:
#                           _id  close_date name  price         source symbol
# 0    5b42789157c41009c0b610d5  2017-06-29  EOS  0.850  CryptoCompare    EOS
# 1    5b42789157c41009c0b610d6  2017-06-30  EOS  0.912  CryptoCompare    EOS
# 746  5b4a3be057c410184dd6f1d1  2017-07-01  EOS  1.010  CoinMarketCap    EOS
# 2    5b42789157c41009c0b610d7  2017-07-01  EOS  1.050  CryptoCompare    EOS
# 3    5b42789157c41009c0b610d8  2017-07-02  EOS  3.000  CryptoCompare    EOS

# %%
def compute_key_dates(df,intervals):
    key_dates = df[['name','close_date']].groupby(['name']).agg('min').reset_index().fillna(datetime.datetime(2099,12,31,0,0))
    for i,d in enumerate(intervals):
        if i == 0:
            key_dates['d0'] = key_dates['close_date']
        else:
            key_dates['d'+str(d)] = key_dates['d0'].apply(lambda x: x + datetime.timedelta(days=int(d)))
            key_dates['d'+str(d)] = key_dates['d'+str(d)].apply(lambda x: datetime.datetime(2018,7,8,0,0) if x > datetime.datetime(2018,7,8,0,0) else x)
        
    return key_dates.drop(columns=['close_date'])

# %%
df2 = df1[['name']].drop_duplicates()
intervals = [0,7,14,30,90,180]
key_dates = compute_key_dates(df1,intervals)
df2 = pd.merge(df2,key_dates,how='left').drop_duplicates()
# add prices
for d in intervals:
    df2 = pd.merge(df2,df1,left_on=['name','d'+str(d)],right_on=['name','close_date'],how='left').fillna(0)
    df2['p'+str(d)] = df2['price']
    if d > 0:
        df2['pch'+str(d)] = df2.apply(lambda x: np.round(x['p'+str(d)]*1.0/x['p0']-1,2),axis=1)
        df2['y'+str(d)] = df2.apply(lambda x: 1 if x['pch'+str(d)] <= -0.5 else 0,axis=1)
    df2 = df2.drop(columns=['price','_id','source','close_date','symbol'])
df2.head()
# Out:
#                      name         d0         d7        d14        d30  \
# 0                  PATRON 2018-05-22 2018-05-29 2018-06-05 2018-06-21
# 1       Sentinel Protocol 2018-07-05 2018-07-08 2018-07-08 2018-07-08
# 2  Blockchain Traded Fund 2018-06-12 2018-06-19 2018-06-26 2018-07-08
# 3                     EOS 2017-06-29 2017-07-06 2017-07-13 2017-07-29
# 4                 Fitrova 2018-05-11 2018-05-18 2018-05-25 2018-06-10
#
#          d90       d180         p0        p7  pch7  y7       p14  pch14  y14  \
# 0 2018-07-08 2018-07-08   0.068146  0.083290  0.22   0  0.052920  -0.22    0
# 1 2018-07-08 2018-07-08   0.057510  0.062690  0.09   0  0.062690   0.09    0
# 2 2018-07-08 2018-07-08  33.590000  3.050000 -0.91   1  1.450000  -0.96    1
# 3 2017-09-27 2017-12-26   0.850000  3.230000  2.80   0  1.710000   1.01    0
# 4 2018-07-08 2018-07-08   0.004725  0.008666  0.83   0  0.002871  -0.39    0
#
#         p30  pch30  y30       p90  pch90  y90      p180  pch180  y180
# 0  0.039430  -0.42    0  0.027960  -0.59    1  0.027960   -0.59     1
# 1  0.062690   0.09    0  0.062690   0.09    0  0.062690    0.09     0
# 2  2.560000  -0.92    1  2.560000  -0.92    1  2.560000   -0.92     1
# 3  1.810000   1.13    0  0.631400  -0.26    0  8.600000    9.12     0
# 4  0.000115  -0.98    1  0.000015  -1.00    1  0.000015   -1.00     1

# %%
db.db['sp_price_features'].delete_many({})
db.db['sp_price_features'].insert_many(df2.to_dict('records'))

# %%
db.toDF('sp_price_features')[['name','d0','p0','d7','p7','pch7','y7','d30','p30','pch30','y30']]
# Out:
#                        name         d0         p0         d7         p7  \
# 0                    PATRON 2018-05-22   0.068146 2018-05-29   0.083290
# 1         Sentinel Protocol 2018-07-05   0.057510 2018-07-08   0.062690
# 2    Blockchain Traded Fund 2018-06-12  33.590000 2018-06-19   3.050000
# 3                       EOS 2017-06-29   0.850000 2017-07-06   3.230000
# 4                   Fitrova 2018-05-11   0.004725 2018-05-18   0.008666
# 5                    RAcoin 2017-12-07   2.860000 2017-12-14   3.470000
# 6                 The Abyss 2018-06-07   0.075560 2018-06-14   0.048080
# 7          Skrumble Network 2018-05-10   0.096480 2018-05-17   0.081565
# 8                    Paymon 2018-06-07   0.003233 2018-06-14   0.003654
# 9                 HashGains 2018-06-21   0.047320 2018-06-28   0.035760
# 10               BitRewards 2016-05-05   0.039830 2016-05-12   0.227000
# 11                 Robotina 2015-01-27   0.000329 2015-02-03   0.000316
# 12                     Holo 2018-04-30   0.000768 2018-05-07   0.001513
# 13    Telegram Open Network 2017-11-15   0.003305 2017-11-22   0.003801
# 14                     ALAX 2018-06-26   0.025786 2018-07-03   0.025850
# 15         Morpheus Network 2018-05-22   0.403338 2018-05-29   0.603457
# 339  -0.15   0 2017-12-09   0.192616  -0.31    0
# 340  -0.75   1 2017-07-16   0.031526  -0.94    1
# 341   0.41   0 2017-07-01   0.000000  -1.00    1
# 342   0.08   0 2017-04-29   0.000000  -1.00    1
# 343   0.21   0 2014-10-17   0.000546  -0.53    1
# 344  -0.21   0 2017-06-23  16.990000   1.74    0
# 345   0.29   0 2017-02-10   0.069197   2.24    0
# 346  -0.08   0 2018-07-08   0.350903  -0.11    0
# 347  -0.06   0 2017-01-09   0.141416   0.29    0
# 348   0.66   0 2016-10-30   0.124068  -0.54    1
#
# [349 rows x 11 columns]

# %%
# Out:
#                           name  close_date
# 0                       PATRON         NaN
# 46           Sentinel Protocol  2018-07-05
# 50      Blockchain Traded Fund  2018-06-12
# 77                         EOS         NaN
# 452                    Fitrova         NaN
# 498                     RAcoin  2017-12-07
# 712                  The Abyss         NaN
# 744           Skrumble Network         NaN
# 779                     Paymon         NaN
# 807                  HashGains  2018-06-21
# 825                 BitRewards  2016-05-05
# 1620                  Robotina  2015-01-27
# 2879                      Holo         NaN
# 2914     Telegram Open Network  2017-11-15
# 3150                      ALAX         NaN
# 3161          Morpheus Network         NaN
# 3199              Lendingblock         NaN
# 3247                   GoChain         NaN
# 3260                      Node  2015-01-26
# 4520                    iOlite  2015-03-06
# 5741                   On.Live  2018-06-06
# 5774                    Eligma  2018-07-04
# 5779                      Amon         NaN
# 5820                      EQUI  2017-08-15
# 6148                  AB-CHAIN  2018-05-24
# 6194                   BitRent         NaN
# 6270                 ClearCoin  2018-07-02
# 6277            Sentinel Chain         NaN
# 6347                 Cappasity         NaN
# 6562                 PHI Token         NaN
# ...                        ...         ...
# 86620                  PARAGON        None
# 87030                     HERO        None
# 87532               Smartlands        None
# 88955                  LAToken        None
# 89460                   Ethbet        None
# 90275               EventChain        None
# 90496                    ZILLA        None
# 92039                     ICOS        None
# 93128                  Aventus        None
# 94265                    NEXUS        None
# 95795                  MONETHA        None
# 96356                     STeX        None
# 96752              TARGET COIN        None
# 97227                 BlockCDN        None
# 97441                   CORION        None
# 100131                    DENT        None
# 101494                NEVERDIE        None
# 102142                SkinCoin        None
# 102843               Encrypgen        None
# 103352                 OmiseGO        None
# 103741               BLOCKPOOL        None
# 105082                    Sonm        None
# 106986                 Ethbits        None
# 107812                    TaaS        None
# 108699                  GNOSIS        None
# 109353                    Qtum        None
# 109763                   Wings        None
# 112446                   Golem        None
# 112476                  DECENT        None
# 113611                 ICONOMI        None
#
# [349 rows x 2 columns]

# %%
df1[['name','close_date']].groupby(['name']).agg('min')
# Out:
#                        close_date
# name
# AB-CHAIN               2018-05-24
# ALAX                          NaN
# ARK                    2017-03-22
# ATFS Project           2018-05-05
# ATLANT                        NaN
# AdEx                   2017-07-01
# AdHive                       None
# Adbank                        NaN
# Aditus                       None
# Adshares                      NaN
# Aeron                         NaN
# AidCoin                       NaN
# AirSwap                2017-08-23
# AirToken               2017-08-25
# Amon                          NaN
# Angel Token            2017-12-28
# Anryze                 2017-11-17
# AppCoins                      NaN
# Artemine               2017-11-08
# Astronaut              2017-11-16
# Auctus                       None
# Authoreon              2018-04-11
# Aventus                2018-07-07
# BABB                          NaN
# BANKEX                        NaN
# BIOTRON                      None
# BLOCKPOOL              2018-07-07
# BMChain                2018-03-05
# Bankera                       NaN
# Basic Attention Token  2017-06-01
# ...                           ...
# Utrum                        None
# VIBEHub                2017-10-11
# VeriME                       None
# Verify                        NaN
# Vezt                          NaN
# Viberate               2017-10-08
# Vice Industry Token    2018-04-18
# Viuly                         NaN
# WAX                          None
# WaBi                          NaN
# Wagerr                 2017-07-06
# WandX                         NaN
# WePower                       NaN
# Wild Crypto            2017-09-12
# Wings                  2018-07-07
# Wolk                   2017-11-01
# Worldcore                     NaN
# Wysker                 2018-07-08
# ZILLA                  2018-07-07
# Zebi                         None
# Zeepin                        NaN
# Zephyr                       None
# ZrCoin                 2015-03-01
# aXpire                        NaN
# carVertical                  None
# fidentiaX                     NaN
# iEx.ec                 2017-04-20
# iOlite                 2015-03-06
# indaHash                     None
# invacio                      None
#
# [349 rows x 1 columns]

# %%
df1[['name','close_date']].groupby(['name']).agg('min').reset_index()['name']
# Out:
# 0                   AB-CHAIN
# 1                       ALAX
# 2                        ARK
# 3               ATFS Project
# 4                     ATLANT
# 5                       AdEx
# 6                     AdHive
# 7                     Adbank
# 8                     Aditus
# 9                   Adshares
# 10                     Aeron
# 11                   AidCoin
# 12                   AirSwap
# 13                  AirToken
# 14                      Amon
# 15               Angel Token
# 16                    Anryze
# 17                  AppCoins
# 18                  Artemine
# 19                 Astronaut
# 20                    Auctus
# 21                 Authoreon
# 22                   Aventus
# 23                      BABB
# 24                    BANKEX
# 25                   BIOTRON
# 26                 BLOCKPOOL
# 27                   BMChain
# 28                   Bankera
# 29     Basic Attention Token
#                ...
# 319                    Utrum
# 320                  VIBEHub
# 321                   VeriME
# 322                   Verify
# 323                     Vezt
# 324                 Viberate
# 325      Vice Industry Token
# 326                    Viuly
# 327                      WAX
# 328                     WaBi
# 329                   Wagerr
# 330                    WandX
# 331                  WePower
# 332              Wild Crypto
# 333                    Wings
# 334                     Wolk
# 335                Worldcore
# 336                   Wysker
# 337                    ZILLA
# 338                     Zebi
# 339                   Zeepin
# 340                   Zephyr
# 341                   ZrCoin
# 342                   aXpire
# 343              carVertical
# 344                fidentiaX
# 345                   iEx.ec
# 346                   iOlite
# 347                 indaHash
# 348                  invacio
# Name: name, Length: 349, dtype: object

# %%
df1['tot_pct_chg'] = df1.apply(lambda x: )

# %%
result = db['ico_subreddit'].find({})

data = []
for i,row in enumerate(result):
    data.append(row)
    
new_master = pd.DataFrame(data)
new_master.head()

# %%
df2 = pd.merge(df1,new_master,how='inner',indicator=True)
df2.groupby(['_merge']).agg('count')

# %%
result = db['ico_tracker'].find({})

data = []
for i,row in enumerate(result):
    data.append(row)
    
new_master = pd.DataFrame(data)
new_master.head()

# %%
df1[df1['symbol'] == 'SOUL'].sort_values(by='close_date')
